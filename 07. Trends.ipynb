# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
subreddit_name = "Nietzsche"

df_subreddit = pd.read_csv(f"{subreddit_name}/{subreddit_name}_mentalhealth_common_author_posts_processed.csv")
df_subreddit['isodate'] = pd.to_datetime(df_subreddit["isodate"])
df_subreddit.drop(['index'], axis = 1, inplace = True)
df_subreddit.head()
# Out:
#               isodate       subreddit           author  \
# 0 2022-10-06 21:54:18       Nietzsche  slavetothegiven
# 1 2022-09-02 20:27:23  realhousewives  slavetothegiven
# 2 2022-08-20 15:14:40  realhousewives  slavetothegiven
# 3 2022-08-20 15:10:18  realhousewives  slavetothegiven
# 4 2022-08-18 16:15:58  realhousewives  slavetothegiven
#
#                                                 body     source  \
# 0  yeh tried all the usual. but i thought it was ...  Nietzsche
# 1  what why on earth is dorit returning and erica...  Nietzsche
# 2                           wait what did teddi say?  Nietzsche
# 3         wait when did Sutton mock her nationality?  Nietzsche
# 4  reality tv is all about getting clearly person...  Nietzsche
#
#                                            processed  Polarity  Subjectivity  \
# 0  ['yeh', 'try', 'usual', 'think', 'kaufmann', '... -0.250000      0.250000
# 1  ['earth', 'dorit', 'return', 'erica', 'demote'...  0.000000      0.750000
# ...

# %%
df_subreddit.groupby(by=['subreddit']).size().sort_values(ascending= False).head(20)
# Out:
# subreddit
# Nietzsche              1149
# AskReddit               394
# Jung                    302
# aspergers               237
# askphilosophy           228
# ADHD                    154
# JordanPeterson          147
# depression              147
# NoFap                   138
# autism                  120
# BPD                     114
# schizophrenia           114
# unpopularopinion        113
# SuicideWatch            106
# nihilism                106
# relationship_advice     105
# redscarepod             100
# conspiracy               96
# Stoicism                 95
# socialskills             90
# dtype: int64

# %%
type(df_subreddit['isodate'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
def get_aggregated_df(agg_cols):
    groupby_str = f"df_subreddit.groupby(by =[pd.Grouper(key='isodate', axis=0, freq='D')] ).agg("
    for col in agg_cols:
        col_string = f"{col}=('{col}', np.sum),"
        groupby_str += col_string
    
    groupby_str = groupby_str[:-1]
    groupby_str += ").reset_index()"
    return eval(groupby_str)

aggregated_df = get_aggregated_df(df_subreddit.columns[-11:])
aggregated_df.head(40)
# Out:
#       isodate  nrc_fear  nrc_anger  nrc_anticip  nrc_trust  nrc_surprise  \
# 0  2011-12-22  0.059509   0.022472          0.0   0.372867      0.167291
# 1  2011-12-23  0.000000   0.000000          0.0   0.000000      0.000000
# 2  2011-12-24  0.000000   0.000000          0.0   0.000000      0.000000
# 3  2011-12-25  0.000000   0.000000          0.0   0.000000      0.000000
# 4  2011-12-26  0.000000   0.000000          0.0   0.000000      0.000000
# 5  2011-12-27  0.000000   0.000000          0.0   0.000000      0.000000
# 6  2011-12-28  0.000000   0.000000          0.0   0.000000      0.000000
# 7  2011-12-29  0.000000   0.000000          0.0   0.000000      0.000000
# 8  2011-12-30  0.000000   0.000000          0.0   0.000000      0.000000
# 9  2011-12-31  0.000000   0.000000          0.0   0.000000      0.000000
# 10 2012-01-01  0.000000   0.000000          0.0   0.000000      0.000000
# 11 2012-01-02  0.000000   0.000000          0.0   0.000000      0.000000
# ...

# %%
aggregated_df["nrc_positive"].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 aggregated_df["nrc_positive"].plot()
#       2 plt.show()
#
# File C:\PythonFolder\RedditScraper\venv\lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File C:\PythonFolder\RedditScraper\venv\lib\site-packages\pandas\plotting\_core.py:1907, in _get_plot_backend(backend)
#    1904 if backend_str in _backends:
#    1905     return _backends[backend_str]
# -> 1907 module = _load_backend(backend_str)
#    1908 _backends[backend_str] = module
# ...
